# %%
import pandas as pd
import numpy as np
import bs4
from bs4 import BeautifulSoup
import requests

# %%
url = requests.get ('https://www.icc-cricket.com/rankings/mens/player-rankings/odi')
url
# Out:
# <Response [200]>

# %%
soup =  BeautifulSoup(url.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI Player Rankings | ICC" property="og:title"/>
# ...

# %%
b_n =  []
for i in soup.find('div', class_ = "rankings-block__banner--name"):
    b_n.append(i.text)
b_n
# Out:
# ['Babar Azam']

# %%
for i in soup.find_all('td', class_ = "table-body__cell name"):
    b_n.append(i.text.replace('\n',''))
    
b_n
# Out:
# ['Babar Azam',
#  'Fakhar Zaman',
#  'Rassie van der Dussen',
#  'Shubman Gill',
#  'Imam-ul-Haq',
#  'David Warner',
#  'Virat Kohli',
#  'Quinton de Kock',
#  'Rohit Sharma',
#  'Steve Smith',
#  'Mohammed Siraj',
#  'Mitchell Starc',
#  'Trent Boult',
#  'Matt Henry',
#  'Rashid Khan',
#  'Adam Zampa',
#  'Mujeeb Ur Rahman',
#  'Shakib Al Hasan',
#  'Shaheen Afridi',
#  'Mohammad Nabi',
#  'Rashid Khan',
#  'Sikandar Raza',
#  'Zeeshan Maqsood',
#  'Mitchell Santner',
#  'Assad Vala',
#  'Mehedi Hasan',
#  'Wanindu Hasaranga',
#  'Chris Woakes',
#  'Fakhar Zaman',
#  'Rassie van der Dussen',
#  'Shubman Gill',
#  'Imam-ul-Haq',
#  'David Warner',
#  'Virat Kohli',
#  'Quinton de Kock',
#  'Rohit Sharma',
#  'Steve Smith',
#  'Mohammed Siraj',
#  'Mitchell Starc',
#  'Trent Boult',
#  'Matt Henry',
#  'Rashid Khan',
#  'Adam Zampa',
#  'Mujeeb Ur Rahman',
#  'Shakib Al Hasan',
#  'Shaheen Afridi',
#  'Mohammad Nabi',
#  'Rashid Khan',
#  'Sikandar Raza',
#  'Zeeshan Maqsood',
# ...

# %%
rating = []
for i in soup.find('div', class_ = "rankings-block__banner--rating"):
    rating.append(i.text)

rating
# Out:
# ['887']

# %%
for i in soup.find_all('td', class_ = "table-body__cell u-text-right rating"):
    rating.append(i.text)
    
rating
# Out:
# ['887',
#  '784',
#  '777',
#  '738',
#  '737',
#  '726',
#  '719',
#  '718',
#  '707',
#  '702',
#  '691',
#  '686',
#  '680',
#  '666',
#  '659',
#  '652',
#  '637',
#  '636',
#  '632',
#  '310',
#  '280',
#  '253',
#  '252',
#  '248',
#  '248',
#  '248',
#  '216',
#  '215',
#  '784',
#  '777',
#  '738',
#  '737',
#  '726',
#  '719',
#  '718',
#  '707',
#  '702',
#  '691',
#  '686',
#  '680',
#  '666',
#  '659',
#  '652',
#  '637',
#  '636',
#  '632',
#  '310',
#  '280',
#  '253',
#  '252',
#  '248',
#  '248',
#  '248',
#  '216',
#  '215']

# %%
team1 = []
    
for i in soup.find('div', class_ = "rankings-block__banner--nationality"):
    team1.append(i.text.replace(' '' ' , '').replace('\n','').replace('887', '').replace(' '' ' , ''))
    
team1
# Out:
# ['', '', '', '', 'PAK', '', '']

# %%
team1.pop(1)
team1
# Out:
# ['PAK',
#  'PAK',
#  'SA',
#  'IND',
#  'PAK',
#  'AUS',
#  'IND',
#  'SA',
#  'IND',
#  'AUS',
#  'IND',
#  'AUS',
#  'NZ',
#  'NZ',
#  'AFG',
#  'AUS',
#  'AFG',
#  'BAN',
#  'PAK',
#  'AFG',
#  'AFG',
#  'ZIM',
#  'OMA',
#  'NZ',
#  'PNG',
#  'BAN',
#  'SL',
#  'ENG',
#  'PAK',
#  'SA',
#  'IND',
#  'PAK',
#  'AUS',
#  'IND',
#  'SA',
#  'IND',
#  'AUS',
#  'IND',
#  'AUS',
#  'NZ',
#  'NZ',
#  'AFG',
#  'AUS',
#  'AFG',
#  'BAN',
#  'PAK',
#  'AFG',
#  'AFG',
#  'ZIM',
#  'OMA',
#  'NZ',
#  'PNG',
#  'BAN',
#  'SL',
#  'ENG']

# %%
for i in soup.find_all('span', class_="table-body__logo-text"):
    team1.append(i.text)
    
team1
# Out:
# ['PAK',
#  '',
#  'PAK',
#  'SA',
#  'IND',
#  'PAK',
#  'AUS',
#  'IND',
#  'SA',
#  'IND',
#  'AUS',
#  'IND',
#  'AUS',
#  'NZ',
#  'NZ',
#  'AFG',
#  'AUS',
#  'AFG',
#  'BAN',
#  'PAK',
#  'AFG',
#  'AFG',
#  'ZIM',
#  'OMA',
#  'NZ',
#  'PNG',
#  'BAN',
#  'SL',
#  'ENG',
#  'PAK',
#  'SA',
#  'IND',
#  'PAK',
#  'AUS',
#  'IND',
#  'SA',
#  'IND',
#  'AUS',
#  'IND',
#  'AUS',
#  'NZ',
#  'NZ',
#  'AFG',
#  'AUS',
#  'AFG',
#  'BAN',
#  'PAK',
#  'AFG',
#  'AFG',
#  'ZIM',
#  'OMA',
#  'NZ',
#  'PNG',
#  'BAN',
#  'SL',
#  'ENG']

# %%
print(len(team1)),print(len(rating)), print(len(b_n))
# Out:
# 55
# 55
# 55
# (None, None, None)

# %%
# ODI bowleres RANKING

# %%
page = requests.get ('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI Team Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI Team Rankings | ICC" property="og:title"/>
# ...

# %%
TEAM = []
RANKING = []
POINTS = []
MATCHES = []

# %%
for i in soup.find_all('span', class_ = "u-hide-phablet"):
    TEAM.append(i.text)
    
TEAM
# Out:
# ['Australia',
#  'India',
#  'Pakistan',
#  'England',
#  'New Zealand',
#  'South Africa',
#  'Bangladesh',
#  'Sri Lanka',
#  'West Indies',
#  'Afghanistan',
#  'Ireland',
#  'Scotland',
#  'Zimbabwe',
#  'Nepal',
#  'Netherlands',
#  'United States',
#  'Namibia',
#  'Oman',
#  'UAE',
#  'Papua New Guinea']

# %%
for i in soup.find('td', class_="rankings-block__banner--matches"):
    MATCHES.append(i.text)
    
MATCHES
# Out:
# ['35']

# %%
points=[]
for i in soup.find('td', class_ ='rankings-block__banner--points'):
    points.append(i.text)
    
points
# Out:
# ['3,965']

# %%
match = []
for i in soup.find('td', class_="table-body__cell u-center-text"):
    match.append(i.text)
    
points=[]
for i in soup.find('td', class_=' table-body__cell u-center-text'):
    points.append(i.text)
    
for i in range(0,len(matches)-1,2):
    matches_list.append(matches[i]) #  teams matches
    points.append(matches[i+1]
# Out:
#   File "C:\Users\Lenovo\AppData\Local\Temp\ipykernel_24368\3273219907.py", line 13
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
for i in range(0,len(matches)-1,2):
    matches_list.append(matches[i]) #  teams matches
    points.append(matches[i+1]) #

# %%
for i in soup5.find_all("td",class_='rankings-block__banner--matches'):

    matches.append(i.text)

for i in soup5.find_all("td",class_='rankings-block__banner--points'):

    points.append(i.text)

for i in soup5.find_all("td",class_='table-body__cell u-center-text'):

    new_list.append(i.text)

for i in range(0,len(new_list)-1,2):

    matches.append(new_list[i])

    points.append(new_list[i+1])

# %%
a= soup.find('td', class_="table-body__cell u-center-text")
a.text
# Out:
# '47'

# %%
a= []
for i in soup.find_all('td', class_="table-body__cell u-center-text"):
    a.append(i.text)
a
# Out:
# ['47',
#  '5,294',
#  '28',
#  '3,133',
#  '36',
#  '3,988',
#  '34',
#  '3,678',
#  '31',
#  '3,141',
#  '38',
#  '3,625',
#  '36',
#  '3,099',
#  '43',
#  '3,105',
#  '20',
#  '1,419',
#  '27',
#  '1,384',
#  '35',
#  '1,567',
#  '31',
#  '1,351',
#  '42',
#  '1,394',
#  '26',
#  '791',
#  '36',
#  '1,093',
#  '37',
#  '1,096',
#  '32',
#  '874',
#  '42',
#  '1,025',
#  '43',
#  '80']

# %%
for i in range(0,len(a)-1,2):
    MATCHES.append(a[i])

# %%
MATCHES
# Out:
# ['35',
#  '47',
#  '28',
#  '36',
#  '34',
#  '31',
#  '38',
#  '36',
#  '43',
#  '20',
#  '27',
#  '35',
#  '31',
#  '42',
#  '26',
#  '36',
#  '37',
#  '32',
#  '42',
#  '43']

# %%
for i in range(0,len(a)-1,2):
    points.append(a[i+1])

# %%
points
# Out:
# ['3,965',
#  '5,294',
#  '3,133',
#  '3,988',
#  '3,678',
#  '3,141',
#  '3,625',
#  '3,099',
#  '3,105',
#  '1,419',
#  '1,384',
#  '1,567',
#  '1,351',
#  '1,394',
#  '791',
#  '1,093',
#  '1,096',
#  '874',
#  '1,025',
#  '80']

# %%
print(len(TEAM)), print(len(MATCHES)), print(len(points))
# Out:
# 20
# 20
# 20
# (None, None, None)

# %%
rating = []
for i in soup.find_all('td', class_ = 'rankings-block__banner--rating u-text-right'):
    rating.append(i.text.replace ('         ', '').replace('\n', '').replace('       ', '' ))
    
rating
# Out:
# [' 113 ']

# %%
for i in soup.find_all('td' , class_ = 'table-body__cell u-text-right rating' ):
    rating.append(i.text)
    
rating
# Out:
# [' 113 ',
#  '113',
#  '112',
#  '111',
#  '108',
#  '101',
#  '95',
#  '86',
#  '72',
#  '71',
#  '51',
#  '45',
#  '44',
#  '33',
#  '30',
#  '30',
#  '30',
#  '27',
#  '24',
#  '2']

# %%
print(' Top 20 Team in ODI')
df2 = pd.DataFrame({'TEAM' : TEAM, 'MATCH':MATCHES, 'POINTS': points, 'RATING': rating })
df2
# Out:
#  Top 20 Team in ODI
#                 TEAM MATCH POINTS RATING
# 0          Australia    35  3,965   113
# 1              India    47  5,294    113
# 2           Pakistan    28  3,133    112
# 3            England    36  3,988    111
# 4        New Zealand    34  3,678    108
# 5       South Africa    31  3,141    101
# 6         Bangladesh    38  3,625     95
# 7          Sri Lanka    36  3,099     86
# 8        West Indies    43  3,105     72
# 9        Afghanistan    20  1,419     71
# 10           Ireland    27  1,384     51
# 11          Scotland    35  1,567     45
# 12          Zimbabwe    31  1,351     44
# 13             Nepal    42  1,394     33
# 14       Netherlands    26    791     30
# 15     United States    36  1,093     30
# 16           Namibia    37  1,096     30
# 17              Oman    32    874     27
# 18               UAE    42  1,025     24
# 19  Papua New Guinea    43     80      2

# %%
# all top 10 bowlers

# %%
page = requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi')
page
# Out:
# <Response [200]>

# %%
soup1 = BeautifulSoup(page.content)
soup1
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="ICC Men's ODI Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Men's ODI Player Rankings | ICC" property="og:title"/>
# ...

# %%
s= soup1.find('a',class_ = 'table-body__cell name')
s

# %%
s.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29296\3806252375.py in <module>
# ----> 1 s.text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
h= soup1.find('div', class_ = 'rankings-block__banner--name')

h.text
# Out:
# 'Babar Azam'

# %%
rating = soup1.find('td', class_ = 'table-body__cell u-text-right rating')
rating
# Out:
# <td class="table-body__cell u-text-right rating">784</td>

# %%
rating.text
# Out:
# '784'

# %%
print(' Top 20 Team in ODI')
df2 = pd.DataFrame({'TEAM' : TEAM, 'MATCH':MATCHES, 'POINTS': points })
df2
# Out:
#  Top 20 Team in ODI
#                 TEAM MATCH POINTS
# 0          Australia    35  3,965
# 1              India    47  5,294
# 2           Pakistan    28  3,133
# 3            England    36  3,988
# 4        New Zealand    34  3,678
# 5       South Africa    31  3,141
# 6         Bangladesh    38  3,625
# 7          Sri Lanka    36  3,099
# 8        West Indies    43  3,105
# 9        Afghanistan    20  1,419
# 10           Ireland    27  1,384
# 11          Scotland    35  1,567
# 12          Zimbabwe    31  1,351
# 13             Nepal    42  1,394
# 14       Netherlands    26    791
# 15     United States    36  1,093
# 16           Namibia    37  1,096
# 17              Oman    32    874
# 18               UAE    42  1,025
# 19  Papua New Guinea    43     80

# %%
df= pd.DataFrame({"Batsman_Name" : b_n, "Rating" : rating, "Team" : team1 })
df
# Out:
#              Batsman_Name Rating Team
# 0              Babar Azam    887  PAK
# 1            Fakhar Zaman    784  PAK
# 2   Rassie van der Dussen    777   SA
# 3            Shubman Gill    738  IND
# 4             Imam-ul-Haq    737  PAK
# 5            David Warner    726  AUS
# 6             Virat Kohli    719  IND
# 7         Quinton de Kock    718   SA
# 8            Rohit Sharma    707  IND
# 9             Steve Smith    702  AUS
# 10         Mohammed Siraj    691  IND
# 11         Mitchell Starc    686  AUS
# 12            Trent Boult    680   NZ
# 13             Matt Henry    666   NZ
# 14            Rashid Khan    659  AFG
# 15             Adam Zampa    652  AUS
# 16       Mujeeb Ur Rahman    637  AFG
# 17        Shakib Al Hasan    636  BAN
# 18         Shaheen Afridi    632  PAK
# 19          Mohammad Nabi    310  AFG
# 20            Rashid Khan    280  AFG
# 21          Sikandar Raza    253  ZIM
# 22        Zeeshan Maqsood    252  OMA
# 23       Mitchell Santner    248   NZ
# ...

# %%
# top 20 bowlers name i could not find because of same class and same tag
